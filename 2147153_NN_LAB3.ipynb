# %% [markdown]
# 1. Explore MLP classifier
# 2. Give a summary of all the parameters used in MLP classifier.
# 3. Classify an XOR problem using the multilayer perceptron Network
# 4. Use atleast 3 different activation functions and give your inference.
# 5. Print the final weight values,

# %% [markdown]
# **1. Explore MLP classifier**
#
# MLPClassifier stands for Multi-layer Perceptron classifier which in the name itself connects to a Neural Network. Unlike other classification algorithms such as Support Vectors or Naive Bayes Classifier, MLPClassifier relies on an underlying Neural Network to perform the task of classification.

# %% [markdown]
# **2. Give a summary of all the parameters used in MLP classifier.**
#
#
#
# hidden_layer_sizes : This parameter allows us to set the number of layers and the number of nodes we wish to have in the Neural Network Classifier. Each element in the tuple represents the number of nodes at the ith position where i is the index of the tuple. Thus the length of tuple denotes the total number of hidden layers in the network.
# max_iter: It denotes the number of epochs.
# activation: The activation function for the hidden layers.
# solver: This parameter specifies the algorithm for weight optimization across the nodes.
# random_state: The parameter allows to set a seed for reproducing the same results

# %% [markdown]
# **3. Classify an XOR problem using the multilayer perceptron Network**

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# **Use atleast 3 different activation functions and give your inference.**

# %%
classifier = MLPClassifier(hidden_layer_sizes=(100, 50, 20), max_iter=200, activation ='relu', solver='adam', random_state=1)

# %% [markdown]
# ReLU function over other activation functions is that it does not activate all the neurons at the same time.

# %% [markdown]
# Adam is an alternative optimization algorithm that provides more efficient neural network weights by running repeated cycles of “adaptive moment estimation.”

# %%
classifier_log = MLPClassifier(hidden_layer_sizes=(100, 50, 20), max_iter=200, activation ='logistic', solver='adam', random_state=1)

# %%
classifier_tanh = MLPClassifier(hidden_layer_sizes=(100, 50, 20), max_iter=200, activation ='tanh', solver='adam', random_state=1)

# %%
X = [
    [0,0],
    [0,1],
    [1,0],
    [1,1]
]

Y = [0, 1, 1, 0]

x_train = X[:2]
y_train = Y[:2]
x_test =X[2:]
y_test = Y[2:]

# %%
# classifier.fit = x_train
classifier.fit(x_train,y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(100, 50, 20), random_state=1)

# %%
y_pred = classifier.predict(x_test)
y_pred
# Out:
# array([0, 1])

# %%
confusion_matrix(y_pred,y_test)
# Out:
# array([[0, 1],
#        [1, 0]])

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.0

# %%
classifier_log.fit(x_train,y_train)
# Out:
# MLPClassifier(activation='logistic', hidden_layer_sizes=(100, 50, 20),
#               random_state=1)

# %%
y_pred=classifier_log.predict(x_test)
y_pred
# Out:
# array([0, 0])

# %%
confusion_matrix(y_pred,y_test)
# Out:
# array([[1, 1],
#        [0, 0]])

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.5

# %%
classifier_tanh.fit(x_train,y_train)
# Out:
# MLPClassifier(activation='tanh', hidden_layer_sizes=(100, 50, 20),
#               random_state=1)

# %%
y_pred=classifier_tanh.predict(x_test)
y_pred
# Out:
# array([0, 1])

# %%
confusion_matrix(y_pred,y_test)
# Out:
# array([[0, 1],
#        [1, 0]])

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.0

# %% [markdown]
# 4 **Print the final weight values**

# %%
classifier.coefs_
# Out:
# [array([[ 6.20443514e-06,  6.34868391e-03, -9.99720629e-02,
#          -3.15931116e-03, -4.25947962e-02, -6.26527902e-02,
#          -2.94644442e-02, -1.96441439e-04, -1.53328041e-05,
#           2.71409767e-06,  7.66896752e-06,  1.89505587e-03,
#          -2.39581635e-02,  5.15248958e-02, -8.86106944e-02,
#           8.41288249e-04,  6.44971886e-06,  3.99570430e-06,
#          -4.48383478e-02, -2.58361501e-02,  2.54912668e-02,
#           8.68201369e-02, -2.01589104e-03,  2.57369383e-03,
#           5.08904067e-02,  5.76729700e-02, -6.54747303e-02,
#          -8.38239056e-02, -3.47478702e-02,  5.15341129e-02,
#          -6.03492865e-02,  8.11261223e-06,  8.25781916e-02,
#          -1.68234584e-06,  2.52779243e-03, -1.83127940e-03,
#           2.00911136e-03,  3.62265585e-02, -9.23756975e-02,
#           1.21718797e-02,  9.53522452e-02,  1.17331981e-02,
#          -6.22221017e-03,  2.21541781e-02, -5.84931580e-02,
#           2.41524424e-06,  6.30126344e-02, -4.25249965e-03,
# ...
